# %%
import pandas as pd

# %%
import numpy as no

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\USER\OneDrive\Documents\globalterrorismdb_0718dist.csv",encoding = 'ISO-8859-1')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(df)
# Out:
# 181691

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df1 = df.iloc[: , :20]

# %%
df1.head(3)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.371887  -99.086624          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
#
#   summary  crit1
# 0     NaN      1
# 1     NaN      1
# 2     NaN      1

# %%
df2 = df.iloc[: , 20:40]

# %%
df2.head()
# Out:
#    crit2  crit3  doubtterr  alternative alternative_txt  multiple  success  \
# 0      1      1        0.0          NaN             NaN       0.0        1
# 1      1      1        0.0          NaN             NaN       0.0        1
# 2      1      1        0.0          NaN             NaN       0.0        1
# 3      1      1        0.0          NaN             NaN       0.0        1
# 4      1      1       -9.0          NaN             NaN       0.0        1
#
#    suicide  attacktype1                 attacktype1_txt  attacktype2  \
# 0        0            1                   Assassination          NaN
# 1        0            6     Hostage Taking (Kidnapping)          NaN
# 2        0            1                   Assassination          NaN
# 3        0            3               Bombing/Explosion          NaN
# 4        0            7  Facility/Infrastructure Attack          NaN
#
#   attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# ...

# %%
df3 = df.iloc[: , 40:60]

# %%
df3.head()
# Out:
#    natlty1         natlty1_txt  targtype2 targtype2_txt  targsubtype2  \
# 0     58.0  Dominican Republic        NaN           NaN           NaN
# 1     21.0             Belgium        NaN           NaN           NaN
# 2    217.0       United States        NaN           NaN           NaN
# 3    217.0       United States        NaN           NaN           NaN
# 4    217.0       United States        NaN           NaN           NaN
#
#   targsubtype2_txt corp2 target2  natlty2 natlty2_txt  targtype3  \
# 0              NaN   NaN     NaN      NaN         NaN        NaN
# 1              NaN   NaN     NaN      NaN         NaN        NaN
# 2              NaN   NaN     NaN      NaN         NaN        NaN
# 3              NaN   NaN     NaN      NaN         NaN        NaN
# 4              NaN   NaN     NaN      NaN         NaN        NaN
#
#   targtype3_txt  targsubtype3 targsubtype3_txt corp3 target3  natlty3  \
# 0           NaN           NaN              NaN   NaN     NaN      NaN
# ...

# %%
df4 = df.iloc[:,60:80]

# %%
df4.head()
# Out:
#   gname2 gsubname2 gname3 gsubname3 motive  guncertain1  guncertain2  \
# 0    NaN       NaN    NaN       NaN    NaN          0.0          NaN
# 1    NaN       NaN    NaN       NaN    NaN          0.0          NaN
# 2    NaN       NaN    NaN       NaN    NaN          0.0          NaN
# 3    NaN       NaN    NaN       NaN    NaN          0.0          NaN
# 4    NaN       NaN    NaN       NaN    NaN          0.0          NaN
#
#    guncertain3  individual  nperps  nperpcap  claimed  claimmode  \
# 0          NaN           0     NaN       NaN      NaN        NaN
# 1          NaN           0     7.0       NaN      NaN        NaN
# 2          NaN           0     NaN       NaN      NaN        NaN
# 3          NaN           0     NaN       NaN      NaN        NaN
# 4          NaN           0     NaN       NaN      NaN        NaN
#
#   claimmode_txt  claim2  claimmode2 claimmode2_txt  claim3  claimmode3  \
# 0           NaN     NaN         NaN            NaN     NaN         NaN
# ...

# %%
df5 = df.iloc[:,80:100]

# %%
df5.head()
# Out:
#    compclaim  weaptype1 weaptype1_txt  weapsubtype1        weapsubtype1_txt  \
# 0        NaN         13       Unknown           NaN                     NaN
# 1        NaN         13       Unknown           NaN                     NaN
# 2        NaN         13       Unknown           NaN                     NaN
# 3        NaN          6    Explosives          16.0  Unknown Explosive Type
# 4        NaN          8    Incendiary           NaN                     NaN
#
#    weaptype2 weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3  \
# 0        NaN           NaN           NaN              NaN        NaN
# 1        NaN           NaN           NaN              NaN        NaN
# 2        NaN           NaN           NaN              NaN        NaN
# 3        NaN           NaN           NaN              NaN        NaN
# 4        NaN           NaN           NaN              NaN        NaN
#
#   weaptype3_txt  weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  \
# ...

# %%
df6 = df.iloc[: , 100:136]

# %%
df6.head()
# Out:
#    nkillter  nwound  nwoundus  nwoundte  property  propextent propextent_txt  \
# 0       NaN     0.0       NaN       NaN         0         NaN            NaN
# 1       NaN     0.0       NaN       NaN         0         NaN            NaN
# 2       NaN     0.0       NaN       NaN         0         NaN            NaN
# 3       NaN     NaN       NaN       NaN         1         NaN            NaN
# 4       NaN     NaN       NaN       NaN         1         NaN            NaN
#
#    propvalue propcomment  ishostkid  ...  addnotes  scite1  scite2  scite3  \
# 0        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 1        NaN         NaN        1.0  ...       NaN     NaN     NaN     NaN
# 2        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 3        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
# 4        NaN         NaN        0.0  ...       NaN     NaN     NaN     NaN
#
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df = df.drop(columns = ["approxdate","resolution","location"])

# %%
df = df.drop(columns = ["gname2","gsubname2","gname3","gsubname3","motive",
"guncertain2","guncertain3","claimmode","claimmode_txt","claim2","claimmode2","claimmode2_txt",
"claim3","claimmode3","claimmode3_txt"])

# %%
df = df.drop(columns = ["compclaim","weaptype2","weaptype2_txt","weapsubtype2","weapsubtype2_txt","weaptype3",
"weaptype3_txt","weapsubtype3","weapsubtype3_txt","weaptype4","weaptype4_txt","weapsubtype4","weapsubtype4_txt"])

# %%
df = df.drop(columns = ["propextent","propextent_txt","propvalue","propcomment","nhostkid",
"nhostkidus","nhours","ndays","divert","kidhijcountry","ransom","ransomamt","ransomamtus","ransompaid","ransompaidus",
"ransomnote","hostkidoutcome","hostkidoutcome_txt","nreleased","addnotes","scite2","scite3","related"])

# %%
df.shape
# Out:
# (181691, 58)

# %%
dfa = df.iloc[:,:20]

# %%
dfb = df.iloc[:,20:40]

# %%
dfc = df.iloc[:,40:]

# %%
dfa.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate           city   latitude  \
# 0       2  Central America & Caribbean       NaN  Santo Domingo  18.456792
# 1       1                North America   Federal    Mexico city  19.371887
# 2       5               Southeast Asia    Tarlac        Unknown  15.478598
# 3       8               Western Europe    Attica         Athens  37.997490
# 4       4                    East Asia   Fukouka        Fukouka  33.580412
#
# ...

# %%
df = df.drop('summary', axis =1)

# %%
dfb.isnull().sum()
# Out:
# multiple                1
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1        10373
# targsubtype1_txt    10373
# corp1               42550
# target1               636
# natlty1              1559
# natlty1_txt          1559
# gname                   0
# guncertain1           380
# individual              0
# nperps              71115
# nperpcap            69489
# claimed             66120
# weaptype1               0
# dtype: int64

# %%
dfc.head()
# Out:
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weapdetail  nkill  \
# 0       Unknown           NaN                     NaN         NaN    1.0
# 1       Unknown           NaN                     NaN         NaN    0.0
# 2       Unknown           NaN                     NaN         NaN    1.0
# 3    Explosives          16.0  Unknown Explosive Type   Explosive    NaN
# 4    Incendiary           NaN                     NaN  Incendiary    NaN
#
#    nkillus  nkillter  nwound  nwoundus  nwoundte  property  ishostkid scite1  \
# 0      NaN       NaN     0.0       NaN       NaN         0        0.0    NaN
# 1      NaN       NaN     0.0       NaN       NaN         0        1.0    NaN
# 2      NaN       NaN     0.0       NaN       NaN         0        0.0    NaN
# 3      NaN       NaN     NaN       NaN       NaN         1        0.0    NaN
# 4      NaN       NaN     NaN       NaN       NaN         1        0.0    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# ...

# %%
dfc.isnull().sum()
# Out:
# weaptype1_txt           0
# weapsubtype1        20768
# weapsubtype1_txt    20768
# weapdetail          67670
# nkill               10313
# nkillus             64446
# nkillter            66958
# nwound              16311
# nwoundus            64702
# nwoundte            69143
# property                0
# ishostkid             178
# scite1              66191
# dbsource                0
# INT_LOG                 0
# INT_IDEO                0
# INT_MISC                0
# INT_ANY                 0
# dtype: int64

# %%
dfa.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate           city   latitude  \
# 0       2  Central America & Caribbean       NaN  Santo Domingo  18.456792
# 1       1                North America   Federal    Mexico city  19.371887
# 2       5               Southeast Asia    Tarlac        Unknown  15.478598
# 3       8               Western Europe    Attica         Athens  37.997490
# 4       4                    East Asia   Fukouka        Fukouka  33.580412
#
# ...

# %%
dfb.head()
# Out:
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0       0.0        1        0            1                   Assassination
# 1       0.0        1        0            6     Hostage Taking (Kidnapping)
# 2       0.0        1        0            1                   Assassination
# 3       0.0        1        0            3               Bombing/Explosion
# 4       0.0        1        0            7  Facility/Infrastructure Attack
#
#    targtype1                targtype1_txt  targsubtype1  \
# 0         14  Private Citizens & Property          68.0
# 1          7      Government (Diplomatic)          45.0
# 2         10          Journalists & Media          54.0
# 3          7      Government (Diplomatic)          46.0
# 4          7      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# ...

# %%
plot1 = df["iyear"].value_counts()

# %%
plot1.plot(kind = 'bar',color = 'r',figsize = (8,8))
# Out:
# <AxesSubplot:>

# %%
plot2 = plot1.to_frame().reset_index()

# %%
plot2.rename(columns = {'index':'year','iyear':'counts'},inplace = True)

# %%
plot2.plot.scatter('year','counts')
# Out:
# <AxesSubplot:xlabel='year', ylabel='counts'>

# %%
plot2 = plot2.sort_values('year')
x_ticks = range(1970,2017)
plt.plot(x_ticks,plot2['counts'])

# %%
plot3=df["country_txt"].value_counts().to_frame().reset_index()

# %%
plot3.rename(columns = {'index':'country_name','country_txt':'v_counts'},inplace = True)

# %%
plot3.sort_values('v_counts',ascending = False)[:10]
# Out:
#      country_name  v_counts
# 0            Iraq     24636
# 1        Pakistan     14368
# 2     Afghanistan     12731
# 3           India     11960
# 4        Colombia      8306
# 5     Philippines      6908
# 6            Peru      6096
# 7     El Salvador      5320
# 8  United Kingdom      5235
# 9          Turkey      4292
